# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 4a: Predict West Nile Virus
#
# ## Part 4 - Combination of Datasets

# %% [markdown]
# ## Import Data

# %% [markdown]
# ### Import all necessary libraries

# %%
# Import all necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import datetime as dt
import re
import string
import nltk

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB

#hide warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Data from both clean datasets

# %%
# %store -r train_df
# %store -r test_df
# %store -r spray_df
# %store -r weather

# %%
train_df.head(2)
# Out:
#         date                                            address  \
# 0 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   species  block           street  trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1          CULEX RESTUANS     41   N OAK PARK AVE  T002
#
#               addressnumberandstreet  latitude  longitude  addressaccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
#
#    nummosquitos  wnvpresent     date_1  month  year  \
# 0             1           0 2007-05-29      5  2007
# 1             1           0 2007-05-29      5  2007
#
#                       geometry  week  yearmonth  yearweek
# 0  POINT (-87.800991 41.95469)    22      20075    200722
# 1  POINT (-87.800991 41.95469)    22      20075    200722

# %%
weather.head(2)
# Out:
#    station       date  t_avg  dew_point  wet_bulb  precip_total  stn_pressure  \
# 0        1 2007-05-01   67.0         51      56.0           0.0         29.10
# 1        2 2007-05-01   68.0         51      57.0           0.0         29.18
#
#    sea_level  result_speed  result_dir  avg_speed  wet_dry  week  month  year  \
# 0      29.82           1.7          27        9.2        0    18      5  2007
# 1      29.82           2.7          25        9.6        0    18      5  2007
#
#    year_month  year_week
# 0       20075     200718
# 1       20075     200718

# %%
train_df['station'] = train_df['latitude'].map(lambda x:1 if x >=41.85 else 2)

# %%
train_merged_df = train_df.merge(weather, how='left', on=['date','station'])

# %%
train_merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10506 entries, 0 to 10505
# Data columns (total 35 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    10506 non-null  datetime64[ns]
#  1   address                 10506 non-null  object
#  2   species                 10506 non-null  object
#  3   block                   10506 non-null  int64
#  4   street                  10506 non-null  object
#  5   trap                    10506 non-null  object
#  6   addressnumberandstreet  10506 non-null  object
#  7   latitude                10506 non-null  float64
#  8   longitude               10506 non-null  float64
#  9   addressaccuracy         10506 non-null  int64
#  10  nummosquitos            10506 non-null  int64
#  11  wnvpresent              10506 non-null  int64
#  12  date_1                  10506 non-null  datetime64[ns]
#  13  month_x                 10506 non-null  int64
#  14  year_x                  10506 non-null  int64
#  15  geometry                10506 non-null  object
#  16  week_x                  10506 non-null  int64
#  17  yearmonth               10506 non-null  int64
#  18  yearweek                10506 non-null  int64
#  19  station                 10506 non-null  int64
#  20  t_avg                   10506 non-null  float64
#  21  dew_point               10506 non-null  int64
#  22  wet_bulb                10506 non-null  float64
#  23  precip_total            10506 non-null  float64
#  24  stn_pressure            10506 non-null  float64
#  25  sea_level               10506 non-null  float64
#  26  result_speed            10506 non-null  float64
#  27  result_dir              10506 non-null  int64
#  28  avg_speed               10506 non-null  float64
#  29  wet_dry                 10506 non-null  int64
#  30  week_y                  10506 non-null  int64
#  31  month_y                 10506 non-null  int64
#  32  year_y                  10506 non-null  int64
#  33  year_month              10506 non-null  int64
#  34  year_week               10506 non-null  int64
# dtypes: datetime64[ns](2), float64(9), int64(18), object(6)
# memory usage: 2.9+ MB

# %%
train_merged_df = pd.get_dummies(columns=['species'], drop_first=True, data = train_merged_df)

# %%
train_merged_df.to_csv('../assets/train_merged_df.csv')

# %%
pd.set_option('display.max_rows', 500)
train_merged_df.corr()
# Out:
#                                    block  latitude  longitude  \
# block                           1.000000  0.091110  -0.090375
# latitude                        0.091110  1.000000  -0.701795
# longitude                      -0.090375 -0.701795   1.000000
# addressaccuracy                 0.222134  0.444026  -0.456775
# nummosquitos                   -0.172388 -0.184806   0.036633
# wnvpresent                      0.004877  0.028697  -0.060345
# month_x                         0.010263 -0.085219   0.097004
# year_x                          0.047036  0.163832  -0.188830
# week_x                         -0.000296 -0.088314   0.099188
# yearmonth                       0.011942 -0.004925   0.012361
# yearweek                        0.047215  0.162730  -0.187612
# station                         0.068595 -0.905456   0.588025
# t_avg                           0.001555 -0.143374   0.135117
# dew_point                      -0.007182 -0.054487   0.079366
# wet_bulb                       -0.005698 -0.100782   0.107681
# precip_total                    0.010258  0.095505  -0.027235
# stn_pressure                    0.011574 -0.237708   0.161224
# sea_level                      -0.005864  0.040776  -0.025194
# result_speed                   -0.004792  0.036771  -0.026462
# result_dir                      0.010134 -0.003439   0.006554
# avg_speed                      -0.010189 -0.006328   0.014069
# wet_dry                         0.012519  0.010225   0.007956
# week_y                         -0.000296 -0.088314   0.099188
# month_y                         0.010263 -0.085219   0.097004
# year_y                          0.047036  0.163832  -0.188830
# year_month                      0.011942 -0.004925   0.012361
# year_week                       0.047215  0.162730  -0.187612
# species_CULEX PIPIENS          -0.069766 -0.144663   0.118359
# species_CULEX PIPIENS/RESTUANS  0.038035  0.062009  -0.050222
# species_CULEX RESTUANS          0.026761  0.094609  -0.082830
# species_CULEX SALINARIUS       -0.011422 -0.012897   0.005761
# species_CULEX TARSALIS         -0.005095 -0.004902   0.009497
# species_CULEX TERRITANS         0.007323 -0.055835   0.063229
#
#                                 addressaccuracy  nummosquitos  wnvpresent  \
# block                                  0.222134     -0.172388    0.004877
# latitude                               0.444026     -0.184806    0.028697
# longitude                             -0.456775      0.036633   -0.060345
# addressaccuracy                        1.000000     -0.248414    0.008064
# nummosquitos                          -0.248414      1.000000    0.196820
# wnvpresent                             0.008064      0.196820    1.000000
# month_x                               -0.074983     -0.026040    0.100143
# year_x                                 0.162514     -0.029611    0.050865
# week_x                                -0.088319     -0.017304    0.100466
# yearmonth                              0.007425     -0.060153   -0.033264
# yearweek                               0.161407     -0.030069    0.053048
# station                               -0.339478      0.122521   -0.024021
# t_avg                                 -0.115932      0.189950    0.062446
# dew_point                             -0.076247      0.160454    0.087021
# wet_bulb                              -0.097435      0.183259    0.081984
# precip_total                           0.034360     -0.022731    0.007789
# stn_pressure                          -0.094353     -0.001219    0.001788
# sea_level                              0.017541     -0.055189    0.007057
# result_speed                           0.012071     -0.006837   -0.046626
# result_dir                             0.010691     -0.024685    0.002554
# avg_speed                             -0.014513      0.018918   -0.031944
# wet_dry                                0.010786      0.039461    0.061490
# week_y                                -0.088319     -0.017304    0.100466
# month_y                               -0.074983     -0.026040    0.100143
# year_y                                 0.162514     -0.029611    0.050865
# year_month                             0.007425     -0.060153   -0.033264
# year_week                              0.161407     -0.030069    0.053048
# species_CULEX PIPIENS                 -0.159680      0.134754    0.096206
# species_CULEX PIPIENS/RESTUANS         0.075106      0.061499    0.010960
# species_CULEX RESTUANS                 0.081840     -0.158393   -0.092094
# species_CULEX SALINARIUS              -0.003257     -0.062886   -0.021373
# species_CULEX TARSALIS                -0.005257     -0.017317   -0.005624
# species_CULEX TERRITANS               -0.022292     -0.096136   -0.034566
#
#                                  month_x    year_x    week_x  yearmonth  ...  \
# block                           0.010263  0.047036 -0.000296   0.011942  ...
# latitude                       -0.085219  0.163832 -0.088314  -0.004925  ...
# longitude                       0.097004 -0.188830  0.099188   0.012361  ...
# addressaccuracy                -0.074983  0.162514 -0.088319   0.007425  ...
# nummosquitos                   -0.026040 -0.029611 -0.017304  -0.060153  ...
# wnvpresent                      0.100143  0.050865  0.100466  -0.033264  ...
# month_x                         1.000000 -0.164287  0.961684   0.354942  ...
# year_x                         -0.164287  1.000000 -0.208008  -0.146044  ...
# week_x                          0.961684 -0.208008  1.000000   0.305353  ...
# yearmonth                       0.354942 -0.146044  0.305353   1.000000  ...
# yearweek                       -0.145940  0.999813 -0.189075  -0.140587  ...
# station                         0.079114 -0.123373  0.078754   0.009047  ...
# t_avg                          -0.025828 -0.130027  0.000455  -0.198524  ...
# dew_point                      -0.024031 -0.146463  0.030588  -0.151015  ...
# wet_bulb                       -0.009052 -0.144830  0.029269  -0.171667  ...
# precip_total                   -0.144521 -0.059423 -0.124189   0.007986  ...
# stn_pressure                    0.351911  0.032962  0.323782   0.033746  ...
# sea_level                       0.356674  0.092076  0.320574   0.046409  ...
# result_speed                   -0.167098  0.114511 -0.144136   0.009178  ...
# result_dir                      0.046754  0.062625  0.096879  -0.009865  ...
# avg_speed                      -0.170461  0.044535 -0.120364  -0.035437  ...
# wet_dry                        -0.125651 -0.040984 -0.066623  -0.057858  ...
# week_y                          0.961684 -0.208008  1.000000   0.305353  ...
# month_y                         1.000000 -0.164287  0.961684   0.354942  ...
# year_y                         -0.164287  1.000000 -0.208008  -0.146044  ...
# year_month                      0.354942 -0.146044  0.305353   1.000000  ...
# year_week                      -0.145940  0.999813 -0.189075  -0.140587  ...
# species_CULEX PIPIENS           0.261550 -0.220509  0.271052   0.053070  ...
# species_CULEX PIPIENS/RESTUANS  0.005906  0.043510  0.009412   0.002621  ...
# species_CULEX RESTUANS         -0.273634  0.189030 -0.290069  -0.062169  ...
# species_CULEX SALINARIUS       -0.017375 -0.032104 -0.018726  -0.008347  ...
# species_CULEX TARSALIS          0.025542  0.007686  0.027980  -0.003920  ...
# species_CULEX TERRITANS         0.026192 -0.039893  0.036084   0.025490  ...
#
#                                  month_y    year_y  year_month  year_week  \
# block                           0.010263  0.047036    0.011942   0.047215
# latitude                       -0.085219  0.163832   -0.004925   0.162730
# longitude                       0.097004 -0.188830    0.012361  -0.187612
# addressaccuracy                -0.074983  0.162514    0.007425   0.161407
# nummosquitos                   -0.026040 -0.029611   -0.060153  -0.030069
# wnvpresent                      0.100143  0.050865   -0.033264   0.053048
# month_x                         1.000000 -0.164287    0.354942  -0.145940
# year_x                         -0.164287  1.000000   -0.146044   0.999813
# week_x                          0.961684 -0.208008    0.305353  -0.189075
# yearmonth                       0.354942 -0.146044    1.000000  -0.140587
# yearweek                       -0.145940  0.999813   -0.140587   1.000000
# station                         0.079114 -0.123373    0.009047  -0.122301
# t_avg                          -0.025828 -0.130027   -0.198524  -0.130528
# dew_point                      -0.024031 -0.146463   -0.151015  -0.146433
# wet_bulb                       -0.009052 -0.144830   -0.171667  -0.144820
# precip_total                   -0.144521 -0.059423    0.007986  -0.062109
# stn_pressure                    0.351911  0.032962    0.033746   0.039485
# sea_level                       0.356674  0.092076    0.046409   0.098767
# result_speed                   -0.167098  0.114511    0.009178   0.112113
# result_dir                      0.046754  0.062625   -0.009865   0.064784
# avg_speed                      -0.170461  0.044535   -0.035437   0.042333
# wet_dry                        -0.125651 -0.040984   -0.057858  -0.042460
# week_y                          0.961684 -0.208008    0.305353  -0.189075
# month_y                         1.000000 -0.164287    0.354942  -0.145940
# year_y                         -0.164287  1.000000   -0.146044   0.999813
# year_month                      0.354942 -0.146044    1.000000  -0.140587
# year_week                      -0.145940  0.999813   -0.140587   1.000000
# species_CULEX PIPIENS           0.261550 -0.220509    0.053070  -0.216021
# species_CULEX PIPIENS/RESTUANS  0.005906  0.043510    0.002621   0.043867
# species_CULEX RESTUANS         -0.273634  0.189030   -0.062169   0.184043
# species_CULEX SALINARIUS       -0.017375 -0.032104   -0.008347  -0.032600
# species_CULEX TARSALIS          0.025542  0.007686   -0.003920   0.008269
# species_CULEX TERRITANS         0.026192 -0.039893    0.025490  -0.039337
#
#                                 species_CULEX PIPIENS  \
# block                                       -0.069766
# latitude                                    -0.144663
# longitude                                    0.118359
# addressaccuracy                             -0.159680
# nummosquitos                                 0.134754
# wnvpresent                                   0.096206
# month_x                                      0.261550
# year_x                                      -0.220509
# week_x                                       0.271052
# yearmonth                                    0.053070
# yearweek                                    -0.216021
# station                                      0.118256
# t_avg                                        0.106661
# dew_point                                    0.111171
# wet_bulb                                     0.116693
# precip_total                                -0.016594
# stn_pressure                                 0.077722
# sea_level                                    0.033921
# result_speed                                -0.101847
# result_dir                                  -0.032512
# avg_speed                                   -0.067606
# wet_dry                                      0.017224
# week_y                                       0.271052
# month_y                                      0.261550
# year_y                                      -0.220509
# year_month                                   0.053070
# year_week                                   -0.216021
# species_CULEX PIPIENS                        1.000000
# species_CULEX PIPIENS/RESTUANS              -0.534334
# species_CULEX RESTUANS                      -0.349250
# species_CULEX SALINARIUS                    -0.053416
# species_CULEX TARSALIS                      -0.014055
# species_CULEX TERRITANS                     -0.086388
#
#                                 species_CULEX PIPIENS/RESTUANS  \
# block                                                 0.038035
# latitude                                              0.062009
# longitude                                            -0.050222
# addressaccuracy                                       0.075106
# nummosquitos                                          0.061499
# wnvpresent                                            0.010960
# month_x                                               0.005906
# year_x                                                0.043510
# week_x                                                0.009412
# yearmonth                                             0.002621
# yearweek                                              0.043867
# station                                              -0.053711
# t_avg                                                -0.027515
# dew_point                                            -0.026418
# wet_bulb                                             -0.028893
# precip_total                                         -0.005276
# stn_pressure                                         -0.026074
# sea_level                                            -0.005960
# result_speed                                          0.012245
# result_dir                                            0.035562
# avg_speed                                             0.002448
# wet_dry                                              -0.001646
# week_y                                                0.009412
# month_y                                               0.005906
# year_y                                                0.043510
# year_month                                            0.002621
# year_week                                             0.043867
# species_CULEX PIPIENS                                -0.534334
# species_CULEX PIPIENS/RESTUANS                        1.000000
# species_CULEX RESTUANS                               -0.539796
# species_CULEX SALINARIUS                             -0.082560
# species_CULEX TARSALIS                               -0.021724
# species_CULEX TERRITANS                              -0.133521
#
#                                 species_CULEX RESTUANS  \
# block                                         0.026761
# latitude                                      0.094609
# longitude                                    -0.082830
# addressaccuracy                               0.081840
# nummosquitos                                 -0.158393
# wnvpresent                                   -0.092094
# month_x                                      -0.273634
# year_x                                        0.189030
# week_x                                       -0.290069
# yearmonth                                    -0.062169
# yearweek                                      0.184043
# station                                      -0.077665
# t_avg                                        -0.083990
# dew_point                                    -0.087144
# wet_bulb                                     -0.090730
# precip_total                                  0.026886
# stn_pressure                                 -0.053817
# sea_level                                    -0.025239
# result_speed                                  0.084316
# result_dir                                   -0.015569
# avg_speed                                     0.057316
# wet_dry                                      -0.005684
# week_y                                       -0.290069
# month_y                                      -0.273634
# year_y                                        0.189030
# year_month                                   -0.062169
# year_week                                     0.184043
# species_CULEX PIPIENS                        -0.349250
# species_CULEX PIPIENS/RESTUANS               -0.539796
# species_CULEX RESTUANS                        1.000000
# species_CULEX SALINARIUS                     -0.053962
# species_CULEX TARSALIS                       -0.014199
# species_CULEX TERRITANS                      -0.087271
#
#                                 species_CULEX SALINARIUS  \
# block                                          -0.011422
# latitude                                       -0.012897
# longitude                                       0.005761
# addressaccuracy                                -0.003257
# nummosquitos                                   -0.062886
# wnvpresent                                     -0.021373
# month_x                                        -0.017375
# year_x                                         -0.032104
# week_x                                         -0.018726
# yearmonth                                      -0.008347
# yearweek                                       -0.032600
# station                                         0.008243
# t_avg                                           0.001649
# dew_point                                      -0.000848
# wet_bulb                                       -0.002067
# precip_total                                    0.002965
# stn_pressure                                   -0.001823
# sea_level                                      -0.008619
# result_speed                                    0.015970
# result_dir                                      0.005978
# avg_speed                                       0.016770
# wet_dry                                        -0.004620
# week_y                                         -0.018726
# month_y                                        -0.017375
# year_y                                         -0.032104
# year_month                                     -0.008347
# year_week                                      -0.032600
# species_CULEX PIPIENS                          -0.053416
# species_CULEX PIPIENS/RESTUANS                 -0.082560
# species_CULEX RESTUANS                         -0.053962
# species_CULEX SALINARIUS                        1.000000
# species_CULEX TARSALIS                         -0.002172
# species_CULEX TERRITANS                        -0.013348
#
#                                 species_CULEX TARSALIS  \
# block                                        -0.005095
# latitude                                     -0.004902
# longitude                                     0.009497
# addressaccuracy                              -0.005257
# nummosquitos                                 -0.017317
# wnvpresent                                   -0.005624
# month_x                                       0.025542
# year_x                                        0.007686
# week_x                                        0.027980
# yearmonth                                    -0.003920
# yearweek                                      0.008269
# station                                       0.007914
# t_avg                                        -0.047092
# dew_point                                    -0.042906
# wet_bulb                                     -0.044727
# precip_total                                 -0.009178
# stn_pressure                                  0.055030
# sea_level                                     0.058197
# result_speed                                 -0.019093
# result_dir                                   -0.013792
# avg_speed                                    -0.024795
# wet_dry                                      -0.011770
# week_y                                        0.027980
# month_y                                       0.025542
# year_y                                        0.007686
# year_month                                   -0.003920
# year_week                                     0.008269
# species_CULEX PIPIENS                        -0.014055
# species_CULEX PIPIENS/RESTUANS               -0.021724
# species_CULEX RESTUANS                       -0.014199
# species_CULEX SALINARIUS                     -0.002172
# species_CULEX TARSALIS                        1.000000
# species_CULEX TERRITANS                      -0.003512
#
#                                 species_CULEX TERRITANS
# block                                          0.007323
# latitude                                      -0.055835
# longitude                                      0.063229
# addressaccuracy                               -0.022292
# nummosquitos                                  -0.096136
# wnvpresent                                    -0.034566
# month_x                                        0.026192
# year_x                                        -0.039893
# week_x                                         0.036084
# yearmonth                                      0.025490
# yearweek                                      -0.039337
# station                                        0.057905
# t_avg                                          0.034481
# dew_point                                      0.027531
# wet_bulb                                       0.031271
# precip_total                                  -0.013484
# stn_pressure                                   0.009860
# sea_level                                     -0.010490
# result_speed                                   0.003071
# result_dir                                     0.021606
# avg_speed                                      0.015922
# wet_dry                                       -0.023877
# week_y                                         0.036084
# month_y                                        0.026192
# year_y                                        -0.039893
# year_month                                     0.025490
# year_week                                     -0.039337
# species_CULEX PIPIENS                         -0.086388
# species_CULEX PIPIENS/RESTUANS                -0.133521
# species_CULEX RESTUANS                        -0.087271
# species_CULEX SALINARIUS                      -0.013348
# species_CULEX TARSALIS                        -0.003512
# species_CULEX TERRITANS                        1.000000
#
# [33 rows x 33 columns]

# %%
corr = train_merged_df.corr()

# %%
#clean up the dataframe using .stack() and .reset_index()
#the columns and the corresponding correlation is displayed side by side in 3 columns
corr_cleaned = corr.stack().reset_index()
#rename the columns accordingly
corr_cleaned.columns = ['var_1', 'var_2', 'correlation']
#further clean the dataframe and remove rows where the correlation = 1.0
#correlation of 1.0 indicates the column's correlation with itself, so we can remove them
corr_cleaned.drop(corr_cleaned[corr_cleaned['correlation'] == 1.0].index, inplace=True)
corr_cleaned.sort_values(by='correlation', ascending=False, inplace=True)
#save those with correlation of more than 0.85 into a separate dataframe to show in heatmap
corr_above_85percent = corr_cleaned.loc[corr_cleaned['correlation'] > 0.60]
#turn corr_above_85percent back into correlation matrix for plotting into heatmap
corr_matrix = corr_above_85percent.pivot(index='var_1', columns='var_2')['correlation']

# %%
# plot correlation heatmap
plt.figure(figsize=(20,20))
sns.heatmap(corr_matrix, annot = True)
plt.tight_layout()

# %%
# plot correlation heatmap
plt.figure(figsize=(20,20))
sns.heatmap(train_merged_df.corr(), annot = True)
plt.tight_layout()

# %%
#pulling the correlation of the columns with the saleprice and sorting it in ascending order
wnvpresent_corr = abs(train_merged_df.corr()[['wnvpresent']]).sort_values('wnvpresent', ascending=True)
#filter correlation dataframe, keep those with correlation lower than 0.05
wnvpresent_corr_below5per = wnvpresent_corr.loc[wnvpresent_corr['wnvpresent'] < 0.05]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(wnvpresent_corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
#pulling the correlation of the columns with the saleprice and sorting it in ascending order
mosquitos_corr = abs(train_merged_df.corr()[['nummosquitos']]).sort_values('nummosquitos', ascending=True)
#filter correlation dataframe, keep those with correlation lower than 0.05
mosquitos_corr_below5per = mosquitos_corr.loc[mosquitos_corr['nummosquitos'] < 0.05]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(mosquitos_corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
train_merged_df.drop(columns=['result_speed','dew_point', 'wet_bulb','week_y','year_y','year_week','yearweek',
                              'year_month','month_y', 'stn_pressure'], inplace=True)

# %%
train_merged_df.columns
# Out:
# Index(['date', 'address', 'block', 'street', 'trap', 'addressnumberandstreet',
#        'latitude', 'longitude', 'addressaccuracy', 'nummosquitos',
#        'wnvpresent', 'date_1', 'month_x', 'year_x', 'geometry', 'week_x',
#        'yearmonth', 'station', 't_avg', 'precip_total', 'sea_level',
#        'result_dir', 'avg_speed', 'wet_dry', 'species_CULEX PIPIENS',
#        'species_CULEX PIPIENS/RESTUANS', 'species_CULEX RESTUANS',
#        'species_CULEX SALINARIUS', 'species_CULEX TARSALIS',
#        'species_CULEX TERRITANS'],
#       dtype='object')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(train_merged_df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
X = train_merged_df.drop(columns=['date','date_1','wnvpresent','address','block','street','trap','addressnumberandstreet',
                                  'addressaccuracy','geometry'], axis=1)

# %%
y = train_merged_df['wnvpresent']

# %%
X.shape
# Out:
# (10506, 20)

# %%
y.shape
# Out:
# (10506,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10506 entries, 0 to 10505
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   latitude                        10506 non-null  float64
#  1   longitude                       10506 non-null  float64
#  2   nummosquitos                    10506 non-null  int64
#  3   month_x                         10506 non-null  int64
#  4   year_x                          10506 non-null  int64
#  5   week_x                          10506 non-null  int64
#  6   yearmonth                       10506 non-null  int64
#  7   station                         10506 non-null  int64
#  8   t_avg                           10506 non-null  float64
#  9   precip_total                    10506 non-null  float64
#  10  sea_level                       10506 non-null  float64
#  11  result_dir                      10506 non-null  int64
#  12  avg_speed                       10506 non-null  float64
#  13  wet_dry                         10506 non-null  int64
#  14  species_CULEX PIPIENS           10506 non-null  uint8
#  15  species_CULEX PIPIENS/RESTUANS  10506 non-null  uint8
#  16  species_CULEX RESTUANS          10506 non-null  uint8
#  17  species_CULEX SALINARIUS        10506 non-null  uint8
#  18  species_CULEX TARSALIS          10506 non-null  uint8
#  19  species_CULEX TERRITANS         10506 non-null  uint8
# dtypes: float64(6), int64(8), uint8(6)
# memory usage: 1.3 MB

# %%
#scale the X values to ensure the variables are all on the same scale
ss = StandardScaler()
X_train_scale = ss.fit_transform(X_train)
X_test_scale = ss.transform(X_test)
